# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv('new_data_actual.csv')

# %%
data.head(-1)
# Out:
#       Depth        WS  RH (%)  Temp (Deg)  PM0.23_0.30  PM0.30_0.40  \
# 0     412.0  2.500000    71.5        26.0         10.1         10.1
# 1     412.0  3.333333    71.3        26.0         10.3         10.4
# 2     412.0  2.222222    71.1        26.1          9.8          9.7
# 3     412.0  2.222222    71.1        26.1         10.1         10.1
# 4     412.0  0.833333    71.0        26.1         10.4         10.5
# ...     ...       ...     ...         ...          ...          ...
# 1857  580.0  0.833333    81.9        24.9          3.8          3.4
# 1858  580.0  1.111111    81.7        24.9          3.8          3.3
# 1859  580.0  0.277778    81.7        24.9          4.0          3.5
# 1860  580.0  1.111111    81.7        25.0          4.0          3.4
# 1861  580.0  1.666667    81.5        25.0          4.0          3.5
#
#       PM0.40_0.50  PM0.50_0.65  PM0.65_0.80  PM0.80_1  PM1_1.6  PM1.6_2  \
# 0             8.7          4.2          1.3       1.0      1.1      3.5
# ...

# %%
data_points = pd.DataFrame()

data_points["Depth"] = data["Depth"]
data_points["WS"] = data["WS"]
data_points["RH (%)"] = data["RH (%)"]
data_points["Temp (Deg)"] = data["Temp (Deg)"]

# %%
data_points = np.array(data_points)

data_target1 = pd.DataFrame(data["PM0.23_0.30"])
data_target1 = np.array(data_target1)
data_target1 = data_target.reshape(1,-1)[0]

data_target2 = pd.DataFrame(data["PM0.30_0.40"])
data_target2 = np.array(data_target2)
data_target2 = data_target.reshape(1,-1)[0]

data_target3 = pd.DataFrame(data["PM0.40_0.50"])
data_target3 = np.array(data_target3)
data_target3= data_target.reshape(1,-1)[0]

data_target4 = pd.DataFrame(data["PM0.50_0.65"])
data_target4 = np.array(data_target4)
data_target4= data_target.reshape(1,-1)[0]

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.utils import check_random_state

from sklearn.svm import SVR
from sklearn.utils import check_random_state

# %% [markdown]
# # svm

# %%
from sklearn.svm import SVR
from sklearn.utils import check_random_state
import numpy as np
rng = check_random_state(47)
X_train,X_test, y_train, y_test = train_test_split(data_points,data_target,random_state=rng)
#n_samples, n_features = 10, 5
#rng = np.random.RandomState(0)
#y = rng.randn(n_samples)
#X = rng.randn(n_samples, n_features)
clf2 = SVR(kernel='rbf',gamma='auto', C=1.0, epsilon=0.1)
clf2.fit(X_train, y_train) 
print("training")
base_accuracy = evaluate(clf2,X_train,y_train)
print("tesiting")
base_accuracy = evaluate(clf2,X_test,y_test)
# Out:
# training
# Model Performance
# Average Error: 0.8955 degrees.
# Accuracy = 88.51%.
# tesiting
# Model Performance
# Average Error: 0.5421 degrees.
# Accuracy = 87.75%.

# %% [markdown]
# # starting adaboost

# %%
i=85773
rng=check_random_state(i)
x_train, x_test, y_train, y_test = train_test_split(data_points,data_target,train_size=0.75,shuffle=True,random_state=rng)

# %%
from sklearn.ensemble import AdaBoostRegressor

# %% [markdown]
# # adabosst for randomforest

# %%
i=85773
rng=check_random_state(i)
base_model2 = AdaBoostRegressor(RandomForestRegressor(warm_start=True,
 verbose= 1,
random_state= rng,
 n_estimators= 800,
 min_weight_fraction_leaf= 0,
 min_samples_split=12,
 min_samples_leaf= 1,
 min_impurity_decrease=0,
 #min_impurity_split=1e-19,
 #max_leaf_nodes=,
 max_features='sqrt',
 max_depth=30,
 criterion= 'mae',
 bootstrap= False,n_jobs=-1),n_estimators=1000,learning_rate=0.5,loss='linear',random_state =rng)
base_model2.fit(x_train,y_train)
#base_accuracy = evaluate(base_model1n_estimators=,, data_points, data_target)
# Out:
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-1)]: Done 192 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=-1)]: Done 442 tasks      | elapsed:    3.2s
# [Parallel(n_jobs=-1)]: Done 792 tasks      | elapsed:    5.7s
# [Parallel(n_jobs=-1)]: Done 800 out of 800 | elapsed:    5.7s finished
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done 192 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done 442 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done 792 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=4)]: Done 800 out of 800 | elapsed:    0.2s finished
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:    0.3s
# ...

# %%
def evaluate(model, test_features, test_labels):
    predictions = model.predict(test_features)
    errors = abs(predictions - test_labels)
    mape = 100 * np.mean(errors / test_labels)
    accuracy = 100 - mape
    print('Model Performance')
    print('Average Error: {:0.4f} degrees.'.format(np.mean(errors)))
    print('Accuracy = {:0.2f}%.'.format(accuracy))
    
    return accuracy
base_accuracy = evaluate(base_model2, x_test,y_test)
# Out:
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done 192 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done 442 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done 792 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=4)]: Done 800 out of 800 | elapsed:    0.2s finished
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done 192 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done 442 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done 792 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=4)]: Done 800 out of 800 | elapsed:    0.2s finished
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    0.0s
# ...

# %%
predicted_y = base_model2.predict(x_test)
MAE = mean_absolute_error(y_test , predicted_y)
sc = r2_score(y_test , predicted_y)
print('Random forest validation MAE = ', MAE)
print('Random forest validation scorers= ', sc)

MsE = mean_squared_error(y_test , predicted_y)

print('Random forest validation MSE = ', MsE)
# Out:
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done 192 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done 442 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done 792 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done 800 out of 800 | elapsed:    0.1s finished
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done 192 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=4)]: Done 442 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done 792 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=4)]: Done 800 out of 800 | elapsed:    0.1s finished
# [Parallel(n_jobs=4)]: Using backend ThreadingBackend with 4 concurrent workers.
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed:    0.0s
# ...

# %%
from yellowbrick.regressor import ResidualsPlot
visualizer = ResidualsPlot(base_model2)
visualizer.fit(x_train, y_train)
visualizer.score(x_test, y_test)  
visualizer.poof()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-42-be1ece62bac4> in <module>
# ----> 1 from yellowbrick.regressor import ResidualsPlot
#       2 visualizer = ResidualsPlot(base_model2)
#       3 visualizer.fit(x_train, y_train)
#       4 visualizer.score(x_test, y_test)
#       5 visualizer.poof()
#
# ModuleNotFoundError: No module named 'yellowbrick'

# %% [markdown]
# # find best parameters for random forest

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor(random_state = 42)
from pprint import pprint
# Look at parameters used by our current forest
print('Parameters currently in use')
pprint(rf.get_params())

# %%
from sklearn.model_selection import RandomizedSearchCV
# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 100, stop = 2000, num = 10)]
# Number of features to consider at every split
max_features = ['auto', 'sqrt','log2']
# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(10, 110, num = 11)]
max_depth.append(None)
# Minimum number of samples required to split a node
min_samples_split = [2, 5, 10,4,6]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 4,5,6]
# Method of selecting samples for training each tree
bootstrap = [True, False]
# Create the random grid
criterion=['mae','mse']
random_state=[int(x) for x in np.linspace(0, 100, num = 100)]
min_weight_fraction_leaf=[round(x,1) for x in np.linspace(0, 0.9, num = 10)]
min_impurity_decrease=[round(x,1) for x in np.linspace(0, 0.9, num = 10)]
warm_start=[True,False]
oob_score=[True,False]
verbose=[0,1,2,3]

random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,
               'bootstrap': bootstrap,
               'criterion':criterion,
               'random_state':random_state,
               'min_weight_fraction_leaf':min_weight_fraction_leaf,
               'warm_start':warm_start,
               'min_impurity_decrease':min_impurity_decrease,
               'oob_score':oob_score,
               'verbose':verbose}
pprint(random_grid)

# %%
# Use the random grid to search for best hyperparameters
# First create the base model to tune
rf = RandomForestRegressor()
# Random search of parameters, using 3 fold cross validation, 
# search across 100 different combinations, and use all available cores
rf_random = RandomizedSearchCV(estimator = rf, param_distributions = random_grid, n_iter = 100, cv = 3, verbose=2, random_state=42, n_jobs = -1)
# Fit the random search model
rf_random.fit(data_points,data_target)

# %%
rf_random.best_params_

# %% [markdown]
# # find accuracy and error in regressor

# %%
def evaluate(model, test_features, test_labels):
    predictions = model.predict(test_features)
    errors = abs(predictions - test_labels)
    mape = 100 * np.mean(errors / test_labels)
    accuracy = 100 - mape
    print('Model Performance')
    print('Average Error: {:0.4f} degrees.'.format(np.mean(errors)))
    print('Accuracy = {:0.2f}%.'.format(accuracy))
    
    return accuracy

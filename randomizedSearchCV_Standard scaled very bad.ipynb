# %%
import numpy as np
from sklearn.utils import check_random_state
import pandas as pd
from sklearn import preprocessing

# %%
data=pd.read_csv('new_data_actual.csv')

# %%
data.head(-1)
# Out:
#       Depth        WS  RH (%)  Temp (Deg)  PM0.23_0.30  PM0.30_0.40  \
# 0     412.0  2.500000    71.5        26.0         10.1         10.1
# 1     412.0  3.333333    71.3        26.0         10.3         10.4
# 2     412.0  2.222222    71.1        26.1          9.8          9.7
# 3     412.0  2.222222    71.1        26.1         10.1         10.1
# 4     412.0  0.833333    71.0        26.1         10.4         10.5
# ...     ...       ...     ...         ...          ...          ...
# 1857  580.0  0.833333    81.9        24.9          3.8          3.4
# 1858  580.0  1.111111    81.7        24.9          3.8          3.3
# 1859  580.0  0.277778    81.7        24.9          4.0          3.5
# 1860  580.0  1.111111    81.7        25.0          4.0          3.4
# 1861  580.0  1.666667    81.5        25.0          4.0          3.5
#
#       PM0.40_0.50  PM0.50_0.65  PM0.65_0.80  PM0.80_1  PM1_1.6  PM1.6_2  \
# 0             8.7          4.2          1.3       1.0      1.1      3.5
# ...

# %%
data_points = pd.DataFrame()
clf =preprocessing.StandardScaler()

# data_points["Depth"] = data["Depth"]
# data_points["WS"] = data["WS"]
# data_points["RH (%)"] = data["RH (%)"]
# data_points["Temp (Deg)"] = data["Temp (Deg)"]

data_points['Depth'] = clf.fit([data.Depth]).transform([data.Depth])[0]
data_points['WS'] = clf.fit([data.WS]).transform([data.WS])[0]
data_points['RH (%)'] = clf.fit([data['RH (%)']]).transform([data['RH (%)']])[0]
data_points['Temp (Deg)'] = clf.fit([data['Temp (Deg)']]).transform([data['Temp (Deg)']])[0]

# %%
data_points = np.array(data_points)

data_target1 = pd.DataFrame(data["PM0.23_0.30"])
data_target1 = np.array(data_target1)
data_target1 = data_target1.reshape(1,-1)[0]

# data_target2 = pd.DataFrame(data["PM0.30_0.40"])
# data_target2 = np.array(data_target2)
# data_target2 = data_target2.reshape(1,-1)[0]

# data_target3 = pd.DataFrame(data["PM0.40_0.50"])
# data_target3 = np.array(data_target3)
# data_target3= data_target3.reshape(1,-1)[0]

# data_target4 = pd.DataFrame(data["PM0.50_0.65"])
# data_target4 = np.array(data_target4)
# data_target4= data_target4.reshape(1,-1)[0]

# data_target5 = pd.DataFrame(data["PM0.50_0.65"])
# data_target5 = np.array(data_target5)
# data_target5= data_target5.reshape(1,-1)[0]

# data_target6 = pd.DataFrame(data["PM0.50_0.65"])
# data_target6 = np.array(data_target6)
# data_target6= data_target6.reshape(1,-1)[0]

# data_target7 = pd.DataFrame(data["PM0.50_0.65"])
# data_target7 = np.array(data_target7)
# data_target7= data_target7.reshape(1,-1)[0]

# data_target8 = pd.DataFrame(data["PM0.50_0.65"])
# data_target8 = np.array(data_target8)
# data_target8= data_target8.reshape(1,-1)[0]

# data_target9 = pd.DataFrame(data["PM0.50_0.65"])
# data_target9 = np.array(data_target9)
# data_target9= data_target9.reshape(1,-1)[0]

# data_target10 = pd.DataFrame(data["PM0.50_0.65"])
# data_target10= np.array(data_target10)
# data_target10 =data_target10.reshape(1,-1)[0]

# data_target11 = pd.DataFrame(data["PM0.50_0.65"])
# data_target11= np.array(data_target11)
# data_target11= data_target11.reshape(1,-1)[0]

# data_target12= pd.DataFrame(data["PM0.50_0.65"])
# data_target12= np.array(data_target12)
# data_target12= data_target12.reshape(1,-1)[0]

# data_target13= pd.DataFrame(data["PM0.50_0.65"])
# data_target13= np.array(data_target13)
# data_target13= data_target13.reshape(1,-1)[0]

# data_target14 = pd.DataFrame(data["PM0.50_0.65"])
# data_target14 = np.array(data_target14)
# data_target14= data_target14.reshape(1,-1)[0]

# data_target15 = pd.DataFrame(data["PM0.50_0.65"])
# data_target15= np.array(data_target15)
# data_target15= data_target15.reshape(1,-1)[0]

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.utils import check_random_state

# %%
def evaluate(model, test_features, test_labels):
    predictions = model.predict(test_features)
    errors = abs(predictions - test_labels)
    mape = 100 * np.mean(errors / test_labels)
    accuracy = 100 - mape
    print('Model Performance')
    print('Average Error: {:0.4f} degrees.'.format(np.mean(errors)))
    print('Accuracy = {:0.2f}%.'.format(accuracy))
    
    return accuracy
#base_accuracy = evaluate(base_model2, x_test,y_test)

# %% [markdown]
# predicted_y = base_model2.predict(x_test)
# MAE = mean_absolute_error(y_test , predicted_y)
# sc = r2_score(y_test , predicted_y)
# print('Random forest validation MAE = ', MAE)
# print('Random forest validation scorers= ', sc)
#
# MsE = mean_squared_error(y_test , predicted_y)
#
# print('Random forest validation MSE = ', MsE)

# %%
from sklearn.model_selection import RandomizedSearchCV
from pprint import pprint
# Number of trees in random forest
n_estimators = [500,800]
# Number of features to consider at every split
max_features = ['auto']
# Maximum number of levels in tree
max_depth = [50]
#max_depth.append(None)
# Minimum number of samples required to split a node
min_samples_split = [2,0.1,3]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1]
# Method of selecting samples for training each tree
bootstrap = [False]
# Create the random grid
criterion=['mae']


i=85773
rng=check_random_state(i)
random_state=[100]


min_weight_fraction_leaf=[0]
min_impurity_decrease=[0]
warm_start=[True]
verbose=[1]
n_jobs=[-1]


random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,
               'bootstrap': bootstrap,
               'criterion':criterion,
               'random_state':random_state,
               'min_weight_fraction_leaf':min_weight_fraction_leaf,
               'warm_start':warm_start,
               'min_impurity_decrease':min_impurity_decrease,
               #'oob_score':oob_score,
               'verbose':verbose,
              'n_jobs':n_jobs}
pprint(random_grid)
# Out:
# {'bootstrap': [False],
#  'criterion': ['mae'],
#  'max_depth': [50],
#  'max_features': ['auto'],
#  'min_impurity_decrease': [0],
#  'min_samples_leaf': [1],
#  'min_samples_split': [2, 0.1, 3],
#  'min_weight_fraction_leaf': [0],
#  'n_estimators': [500, 800],
#  'n_jobs': [-1],
#  'random_state': [100],
#  'verbose': [1],
#  'warm_start': [True]}

# %%
# Use the random grid to search for best hyperparameters
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import fbeta_score, make_scorer
from sklearn.metrics import mean_absolute_error
#sklearn.metrics.mean_absolute_erro
ftwo_scorer = make_scorer(mean_absolute_error)
# First create the base model to tune
rf = RandomForestRegressor()
# Random search of parameters, using 3 fold cross validation, 
# search across 100 different combinations, and use all available cores
#rf_random = RandomizedSearchCV(estimator = rf, param_distributions = random_grid,scoring=ftwo_scorer,n_iter = 10, cv = 5, verbose=1, n_jobs = -1,return_train_score=True)
rf_random1 = RandomizedSearchCV(estimator = rf, param_distributions = random_grid,scoring=ftwo_scorer, n_iter = 10, cv = 5, verbose=1, n_jobs = -1,return_train_score=True)
# rf_random2 = RandomizedSearchCV(estimator = rf, param_distributions = random_grid,scoring=ftwo_scorer, n_iter = 10, cv = 5, verbose=1, n_jobs = -1,return_train_score=True)
# rf_random3 = RandomizedSearchCV(estimator = rf, param_distributions = random_grid,scoring=ftwo_scorer, n_iter = 10, cv = 5, verbose=1, n_jobs = -1,return_train_score=True)
# rf_random4 = RandomizedSearchCV(estimator = rf, param_distributions = random_grid,scoring=ftwo_scorer, n_iter = 10, cv = 8, verbose=1, n_jobs = -1,return_train_score=True)
# rf_random5 = RandomizedSearchCV(estimator = rf, param_distributions = random_grid,scoring=ftwo_scorer, n_iter = 10, cv = 5, verbose=1, n_jobs = -1,return_train_score=True)
# rf_random6 = RandomizedSearchCV(estimator = rf, param_distributions = random_grid,scoring=ftwo_scorer, n_iter = 10, cv = 5, verbose=1, n_jobs = -1,return_train_score=True)
# rf_random7 = RandomizedSearchCV(estimator = rf, param_distributions = random_grid,scoring=ftwo_scorer, n_iter = 10, cv = 5, verbose=1, n_jobs = -1,return_train_score=True)
# rf_random8 = RandomizedSearchCV(estimator = rf, param_distributions = random_grid,scoring=ftwo_scorer, n_iter = 10, cv = 5, verbose=1, n_jobs = -1,return_train_score=True)
# rf_random9 = RandomizedSearchCV(estimator = rf, param_distributions = random_grid,scoring=ftwo_scorer, n_iter = 10, cv = 5, verbose=1, n_jobs = -1,return_train_score=True)
# rf_random10 = RandomizedSearchCV(estimator = rf, param_distributions = random_grid,scoring=ftwo_scorer, n_iter = 10, cv = 5, verbose=1, n_jobs = -1,return_train_score=True)
# rf_random11 = RandomizedSearchCV(estimator = rf, param_distributions = random_grid,scoring=ftwo_scorer, n_iter = 10, cv = 5, verbose=1, n_jobs = -1,return_train_score=True)
# rf_random12 = RandomizedSearchCV(estimator = rf, param_distributions = random_grid,scoring=ftwo_scorer, n_iter = 10, cv = 5, verbose=1, n_jobs = -1,return_train_score=True)
# rf_random13 = RandomizedSearchCV(estimator = rf, param_distributions = random_grid,scoring=ftwo_scorer, n_iter = 10, cv = 5, verbose=1, n_jobs = -1,return_train_score=True)
# rf_random14 = RandomizedSearchCV(estimator = rf, param_distributions = random_grid,scoring=ftwo_scorer, n_iter = 10, cv = 5, verbose=1, n_jobs = -1,return_train_score=True)
# rf_random15 = RandomizedSearchCV(estimator = rf, param_distributions = random_grid,scoring=ftwo_scorer, n_iter = 10, cv = 5, verbose=1, n_jobs = -1,return_train_score=True)
# # Fit the random search model

rf_random1.fit(data_points,data_target1)
# rf_random2.fit(data_points,data_target2)
# rf_random3.fit(data_points,data_target3)
# rf_random4.fit(data_points,data_target4)
# rf_random5.fit(data_points,data_target5)
# rf_random6.fit(data_points,data_target6)
# rf_random7.fit(data_points,data_target7)
# rf_random8.fit(data_points,data_target8)
# rf_random9.fit(data_points,data_target9)
# rf_random10.fit(data_points,data_target10)
# rf_random11.fit(data_points,data_target11)
# rf_random12.fit(data_points,data_target12)
# rf_random13.fit(data_points,data_target13)
# rf_random14.fit(data_points,data_target14)
# rf_random15.fit(data_points,data_target15)
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# C:\Users\sande\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:266: UserWarning: The total space of parameters 6 is smaller than n_iter=10. Running 6 iterations. For exhaustive searches, use GridSearchCV.
#   % (grid_size, self.n_iter, grid_size), UserWarning)
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:   10.3s finished
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=-1)]: Done 434 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done 784 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Done 800 out of 800 | elapsed:    0.3s finished
# RandomizedSearchCV(cv=5, error_score='raise-deprecating',
# ...

# %%
print("target 1")
print("\n")
#evaluate(rf_random,data_points,data_target1)
evaluate(rf_random1,data_points,data_target1) 
# print("target 2")
# print("\n")
# evaluate(rf_random2,data_points,data_target2) 
# print("target 3")
# print("\n")
# evaluate(rf_random3,data_points,data_target3) 
# print("target 4")
# print("\n")
# evaluate(rf_random4,data_points,data_target4)
# print("target 5")
# print("\n")
# evaluate(rf_random5,data_points,data_target5) 
# print("target 6")
# print("\n")
# evaluate(rf_random6,data_points,data_target6)
# print("target 7")
# print("\n")
# evaluate(rf_random7,data_points,data_target7) 
# print("target 8")
# print("\n")
# evaluate(rf_random8,data_points,data_target8) 
# print("target 9")
# print("\n")
# evaluate(rf_random9,data_points,data_target9) 
# print("target 10")
# print("\n")
# evaluate(rf_random10,data_points,data_target10)
# print("target 11")
# print("\n")
# evaluate(rf_random11,data_points,data_target11) 
# print("target 12")
# print("\n")
# evaluate(rf_random12,data_points,data_target12) 
# print("target 13")
# print("\n")
# evaluate(rf_random13,data_points,data_target13) 
# print("target 14")
# print("\n")
# evaluate(rf_random14,data_points,data_target14) 
# print("target 15")
# print("\n")
# evaluate(rf_random15,data_points,data_target15)
# Out:
# target 1
# [Parallel(n_jobs=8)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=8)]: Done  34 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 184 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 434 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 784 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=8)]: Done 800 out of 800 | elapsed:    0.0s finished
# Model Performance
# Average Error: 4.1025 degrees.
# Accuracy = -9.08%.
# -9.0782211456294

# %%
import pickle

# %%
model1 = open('model1.pkl', 'wb')
pickle.dump(rf_random1,model1)

# %% [markdown]
# for i in range(2,16):
#     print("model{} = open('model{}.pkl', 'wb')".format(i,i))
#     print("pickle.dump(rf_random{},model{})".format(i,i))

# %%
# model2 = open('model2.pkl', 'wb')
# pickle.dump(rf_random2,model2)
# model3 = open('model3.pkl', 'wb')
# pickle.dump(rf_random3,model3)
# model4 = open('model4.pkl', 'wb')
# pickle.dump(rf_random4,model4)
# model5 = open('model5.pkl', 'wb')
# pickle.dump(rf_random5,model5)
# model6 = open('model6.pkl', 'wb')
# pickle.dump(rf_random6,model6)
# model7 = open('model7.pkl', 'wb')
# pickle.dump(rf_random7,model7)
# model8 = open('model8.pkl', 'wb')
# pickle.dump(rf_random8,model8)
# model9 = open('model9.pkl', 'wb')
# pickle.dump(rf_random9,model9)
# model10 = open('model10.pkl', 'wb')
# pickle.dump(rf_random10,model10)
# model11 = open('model11.pkl', 'wb')
# pickle.dump(rf_random11,model11)
# model12 = open('model12.pkl', 'wb')
# pickle.dump(rf_random12,model12)
# model13 = open('model13.pkl', 'wb')
# pickle.dump(rf_random13,model13)
# model14 = open('model14.pkl', 'wb')
# pickle.dump(rf_random14,model14)
# model15 = open('model15.pkl', 'wb')
# pickle.dump(rf_random15,model15)
